# %%
def who_goes_first():
  import random
  x = random.randrange(1,11)
  
  if x%2 == 0:
    return 'Player2'
  else:
    return 'Player1'

# %%
def start_game(p):
  
  while p not in ['X','O']:
    #print(player1)
    p = input("Please pick a marker 'X' or'O'").upper()

    if p not in ['X','O']:
      print('Please pick an X or O.')
   
  return p.upper()

# %%
def player1_picks():
  p1pick = int(input('Player1 make your pick'))
  
    
  while picks[p1pick] in ['X','O']:
    print('That square is already taken. Pick again.')
    p1pick = int(input('Player1 make your pick'))

  picks[p1pick] = player1
  print ('Player1 picked square '+ str(p1pick))

# %%
def player2_picks():
  p2pick = int(input('Player2 make your pick'))
  
  
  
  while picks[p2pick] in ['X','O']:
    print('That square is already taken. Pick again.')
    p2pick = int(input('Player2 make your pick'))

  picks[p2pick] = player2
  print ('Player2 picked square '+ str(p2pick))

# %%
#player2_picks()

# %%
from IPython.display import clear_output
def display_board(board):
  clear_output()
  print(board[7]+'|'+board[8]+'|'+board[9])
  print('-----')
  print(board[4]+'|'+board[5]+'|'+board[6])
  print('-----')
  print(board[1]+'|'+board[2]+'|'+board[3])

# %%
def winner(pick_list,marker):
  return((pick_list[7]==marker and pick_list[8]==marker and pick_list[9]) or #top row
         (pick_list[4]==marker and pick_list[5]==marker and pick_list[6]) or #middle row
         (pick_list[1]==marker and pick_list[2]==marker and pick_list[3]) or #bottom row
         (pick_list[7]==marker and pick_list[4]==marker and pick_list[1]) or #left column
         (pick_list[8]==marker and pick_list[5]==marker and pick_list[2]) or #middle column
         (pick_list[9]==marker and pick_list[6]==marker and pick_list[3]) or #right column
         (pick_list[7]==marker and pick_list[5]==marker and pick_list[3]) or #diagonal
         (pick_list[1]==marker and pick_list[5]==marker and pick_list[9])) #diagonal

# %%
winner(picks,player2)
# Out:
# ' '

# %%
picks.values()
picks[2]
# Out:
# 'X'

# %%
player2
# Out:
# 'X'

# %%
def board_full(picks):
  return ' ' == picks.values()

# %%
#initialize player markers
player1 = 'z'
player2 = 'z'
#initalize player picks
picks={1:' ',2:' ',3:' ',4:' ',5:' ',6:' ',7:' ',8:' ',9:' '}

go_first = who_goes_first()

if go_first == 'Player1':
  print('Player1 goes first')
  player1 = start_game('a')
  if player1 == 'X':
    player2 = 'O'
  else:
    player2 ='X'
else:
  print('Player2 goes first')
  player2 = start_game('a')
  if player2 =='X':
    player1 = 'O'
  else:
    player1 = 'X'
game_on= True

while game_on:
  
  print('go_first = ' + go_first)

  if go_first == 'Player1':

    #print('11')
    player1_picks()
    #print('12')
    if winner(picks,player1):
      display_board(picks)
      print('Congratulation Player1 you won')
      game_on = False
    elif board_full(picks):
      print('Board is full. The game is a draw')
      game_on = False
    else:
      go_first = 'Player2'
      
  else:
    #print('21')
    player2_picks()
    #print('22')
    if winner(picks,player2):
      display_board(picks)
      print('Congratulation Player2 you won')
      game_on = False
    elif board_full(picks):
      print('Board is full. The game is a draw')
      game_on = False
    else:
      go_first = 'Player1'
# Out:
#  | |
# -----
#  | |
# -----
# X| |
# go_first = Player2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     729             try:
# --> 730                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     731             except Exception:
#
# /usr/local/lib/python3.6/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.6/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     465         """
# --> 466         parts = [self.recv(flags, copy=copy, track=track)]
#     467         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.6/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-98-063ecd2dc1d3> in <module>()
#      43   else:
#      44     #print('21')
# ---> 45     player2_picks()
#      46     #print('22')
#      47     if winner(picks,player2):
#
# <ipython-input-72-6af1ad8f5e56> in player2_picks()
#       1 def player2_picks():
# ----> 2   p2pick = int(input('Player2 make your pick'))
#       3
#       4   #print(picks[p1pick])
#       5
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     703             self._parent_ident,
#     704             self._parent_header,
# --> 705             password=False,
#     706         )
#     707
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     733             except KeyboardInterrupt:
#     734                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 735                 raise KeyboardInterrupt
#     736             else:
#     737                 break
#
# KeyboardInterrupt:
